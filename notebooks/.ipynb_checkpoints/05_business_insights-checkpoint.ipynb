# %%
from IPython.display import Image, display

display(Image(filename="../visuals/top_10_countries.png"))

# %% [markdown]
# Le Royaume-Uni écrase totalement le reste du classement avec un revenu dépassant les 7 millions d'unités. Cette domination sans partage montre que l'activité repose quasiment sur un seul marché, ce qui représente un risque de dépendance critique.
# Le reste du Top 10, mené par les Pays-Bas, l'Irlande et l'Allemagne, affiche des revenus très faibles en comparaison (sous la barre des 500 000 unités). Ces pays constituent toutefois des relais de croissance inexploités.
# En résumé, l'entreprise est très performante localement mais vulnérable à l'international. La priorité stratégique est de diversifier les revenus vers l'Europe continentale pour sécuriser l'avenir du business.
